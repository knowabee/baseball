# %% [markdown]
# ## Standard libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data

# %%
# This is the full dataset 
full_data = pd.read_excel("C:/Users/bodin/School/STAT 5001/project/baseballdata.xlsx")
full_data.head()
# Out:
#        date  game_num day_of_week away_team away_league  away_game_num  \
# 0  18710504         0         Thu       CL1         NaN              1
# 1  18710505         0         Fri       BS1         NaN              1
# 2  18710506         0         Sat       CL1         NaN              2
# 3  18710508         0         Mon       CL1         NaN              3
# 4  18710509         0         Tue       BS1         NaN              2
#
#   home_team home_league  home_game_num  away_score  ...   home_7_name  \
# 0       FW1         NaN              1           0  ...    Ed Mincher
# 1       WS3         NaN              1          20  ...  Asa Brainard
# 2       RC1         NaN              1          12  ...    Pony Sager
# 3       CH1         NaN              1          12  ...      Ed Duffy
# 4       TRO         NaN              1           9  ...  Steve Bellan
#
#    home_7_pos home_8_id      home_8_name home_8_pos home_9_id  \
# 0         7.0  mcdej101  James McDermott        8.0  kellb105
# 1         1.0  burrh101  Henry Burroughs        9.0  berth101
# 2         6.0  birdg101      George Bird        7.0  stirg101
# 3         6.0  pinke101       Ed Pinkham        5.0  zettg101
# 4         5.0  pikel101         Lip Pike        3.0  cravb101
#
#        home_9_name  home_9_pos  additional_info acquisition_info
# 0       Bill Kelly         9.0              NaN                D
# 1  Henry Berthrong         8.0             HTBF                D
# 2       Gat Stires         9.0              NaN                D
# 3  George Zettlein         1.0              NaN                D
# 4      Bill Craver         6.0             HTBF                D
#
# [5 rows x 161 columns]

# %% [markdown]
# ## Manipulate Data

# %%
# Reduce data to include only games from the year 2000+
data_reduced = full_data[full_data['date'] > 20000101]     #yyyymmdd

# Only include variables specified in write-up
data = data_reduced[['away_AB', 'away_H', 'away_2B', 'away_3B',
             'away_HR', 'away_SH', 'away_SF', 'away_HBP', 
             'away_BB', 'away_IBB', 'away_K', 'away_SB', 'away_CS', 
             'away_GIDP', 'away_CI', 'away_score', 
             'home_AB', 'home_H', 'home_2B', 'home_3B', 
             'home_HR', 'home_SH', 'home_SF', 'home_HBP', 
             'home_BB', 'home_IBB', 'home_K', 'home_SB', 'home_CS', 
             'home_GIDP', 'home_CI', 'home_score']]

# %%
# Ensure no 'na' values
data = data.dropna()

# Add singles column as specified in our write-up
data['away_1B'] = data['away_H'] - data['away_2B'] - data['away_3B'] - data['away_HR']
data['home_1B'] = data['home_H'] - data['home_2B'] - data['home_3B'] - data['home_HR']

# %%
# Combine away and home data columns
data2 = pd.DataFrame()

data2['AB'] = pd.concat([data['away_AB'], data['home_AB']], ignore_index=True)
data2['H'] = pd.concat([data['away_H'], data['home_H']], ignore_index=True)
data2['1B'] = pd.concat([data['away_1B'], data['home_1B']], ignore_index=True)
data2['2B'] = pd.concat([data['away_2B'], data['home_2B']], ignore_index=True)
data2['3B'] = pd.concat([data['away_3B'], data['home_3B']], ignore_index=True)
data2['HR'] = pd.concat([data['away_HR'], data['home_HR']], ignore_index=True)
data2['SH'] = pd.concat([data['away_SH'], data['home_SH']], ignore_index=True)
data2['SF'] = pd.concat([data['away_SF'], data['home_SF']], ignore_index=True)
data2['HBP'] = pd.concat([data['away_HBP'], data['home_HBP']], ignore_index=True)
data2['BB'] = pd.concat([data['away_BB'], data['home_BB']], ignore_index=True)
data2['IBB'] = pd.concat([data['away_IBB'], data['home_IBB']], ignore_index=True)
data2['K'] = pd.concat([data['away_K'], data['home_K']], ignore_index=True)
data2['SB'] = pd.concat([data['away_SB'], data['home_SB']], ignore_index=True)
data2['CS'] = pd.concat([data['away_CS'], data['home_CS']], ignore_index=True)
data2['GIDP'] = pd.concat([data['away_GIDP'], data['home_GIDP']], ignore_index=True)
data2['CI'] = pd.concat([data['away_CI'], data['home_CI']], ignore_index=True)
data2['SCORE'] = pd.concat([data['away_score'], data['home_score']], ignore_index=True)

# %%
# Split into input and output variables
X = data2.drop('SCORE', axis=1)
y = data2['SCORE']

# %%
# Split data into training and test sets
from sklearn.model_selection import train_test_split
np.random.seed(42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Standardize data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Perform neural network regression (1)

# %%
# Initialize model
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(32, activation="relu", input_shape=(16,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1)
])

# Compile model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Train model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1401 - val_loss: 2.1870
# Epoch 2/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1382 - val_loss: 2.1531
# Epoch 3/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1370 - val_loss: 2.2352
# Epoch 4/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1361 - val_loss: 2.2168
# Epoch 5/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1350 - val_loss: 2.1557
# Epoch 6/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1354 - val_loss: 2.1577
# Epoch 7/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1366 - val_loss: 2.1447
# Epoch 8/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1343 - val_loss: 2.1635
# Epoch 9/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1356 - val_loss: 2.2470
# Epoch 10/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1344 - val_loss: 2.1622
# Epoch 11/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1336 - val_loss: 2.1463
# Epoch 12/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1303 - val_loss: 2.2027
# Epoch 13/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1330 - val_loss: 2.1683
# Epoch 14/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1273 - val_loss: 2.1550
# Epoch 15/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1296 - val_loss: 2.1467
# Epoch 16/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1315 - val_loss: 2.1448
# Epoch 17/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1291 - val_loss: 2.1456
# Epoch 18/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1292 - val_loss: 2.1551
# Epoch 19/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1291 - val_loss: 2.1697
# Epoch 20/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1264 - val_loss: 2.1583
# Epoch 21/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1280 - val_loss: 2.1521
# Epoch 22/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1262 - val_loss: 2.1854
# Epoch 23/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1251 - val_loss: 2.2004
# Epoch 24/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1261 - val_loss: 2.1647
# Epoch 25/100
# 2207/2207 [==============================] - 3s 2ms/step - loss: 2.1260 - val_loss: 2.1459
# Epoch 26/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1249 - val_loss: 2.2055
# Epoch 27/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1294 - val_loss: 2.1420
# Epoch 28/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1228 - val_loss: 2.1874
# Epoch 29/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1246 - val_loss: 2.1562
# Epoch 30/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1250 - val_loss: 2.1520
# Epoch 31/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1271 - val_loss: 2.1471
# Epoch 32/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1224 - val_loss: 2.1591
# Epoch 33/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1241 - val_loss: 2.1493
# Epoch 34/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1197 - val_loss: 2.1457
# Epoch 35/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1211 - val_loss: 2.1445
# Epoch 36/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1213 - val_loss: 2.1452
# Epoch 37/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1197 - val_loss: 2.1449
# Epoch 38/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1210 - val_loss: 2.1900
# Epoch 39/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1202 - val_loss: 2.1639
# Epoch 40/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1221 - val_loss: 2.1684
# Epoch 41/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1195 - val_loss: 2.1582
# Epoch 42/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1195 - val_loss: 2.1553
# Epoch 43/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1220 - val_loss: 2.1797
# Epoch 44/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1237 - val_loss: 2.1559
# Epoch 45/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1197 - val_loss: 2.1645
# Epoch 46/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1172 - val_loss: 2.1545
# Epoch 47/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1202 - val_loss: 2.1471
# Epoch 48/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1186 - val_loss: 2.1547
# Epoch 49/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1185 - val_loss: 2.1472
# Epoch 50/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1192 - val_loss: 2.2180
# Epoch 51/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1174 - val_loss: 2.1654
# Epoch 52/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1172 - val_loss: 2.1499
# Epoch 53/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1171 - val_loss: 2.3068
# Epoch 54/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1181 - val_loss: 2.1507
# Epoch 55/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1154 - val_loss: 2.1784
# Epoch 56/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1154 - val_loss: 2.1445
# Epoch 57/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1163 - val_loss: 2.1586
# Epoch 58/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1171 - val_loss: 2.1569
# Epoch 59/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1150 - val_loss: 2.1542
# Epoch 60/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1162 - val_loss: 2.1552
# Epoch 61/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1155 - val_loss: 2.1499
# Epoch 62/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1131 - val_loss: 2.1528
# Epoch 63/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1150 - val_loss: 2.1433
# Epoch 64/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1159 - val_loss: 2.2126
# Epoch 65/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1144 - val_loss: 2.1965
# Epoch 66/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1141 - val_loss: 2.1609
# Epoch 67/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1160 - val_loss: 2.1611
# Epoch 68/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1152 - val_loss: 2.1533
# Epoch 69/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1151 - val_loss: 2.1519
# Epoch 70/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1168 - val_loss: 2.1462
# Epoch 71/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1135 - val_loss: 2.1490
# Epoch 72/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1124 - val_loss: 2.1772
# Epoch 73/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1140 - val_loss: 2.1480
# Epoch 74/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1119 - val_loss: 2.1608
# Epoch 75/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1129 - val_loss: 2.1794
# Epoch 76/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1124 - val_loss: 2.1979
# Epoch 77/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1117 - val_loss: 2.1740
# Epoch 78/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1135 - val_loss: 2.1556
# Epoch 79/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1131 - val_loss: 2.2032
# Epoch 80/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1103 - val_loss: 2.1543
# Epoch 81/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1118 - val_loss: 2.1653
# Epoch 82/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1130 - val_loss: 2.1574
# Epoch 83/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1090 - val_loss: 2.1577
# Epoch 84/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1114 - val_loss: 2.1644
# Epoch 85/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1095 - val_loss: 2.1652
# Epoch 86/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1087 - val_loss: 2.1556
# Epoch 87/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1095 - val_loss: 2.2192
# Epoch 88/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1087 - val_loss: 2.1510
# Epoch 89/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1111 - val_loss: 2.1554
# Epoch 90/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1097 - val_loss: 2.1770
# Epoch 91/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1111 - val_loss: 2.1611
# Epoch 92/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1089 - val_loss: 2.1636
# Epoch 93/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1098 - val_loss: 2.1741
# Epoch 94/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1111 - val_loss: 2.1618
# Epoch 95/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1110 - val_loss: 2.1538
# Epoch 96/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1107 - val_loss: 2.1807
# Epoch 97/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1069 - val_loss: 2.1874
# Epoch 98/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1069 - val_loss: 2.1638
# Epoch 99/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1087 - val_loss: 2.1601
# Epoch 100/100
# 2207/2207 [==============================] - 3s 1ms/step - loss: 2.1089 - val_loss: 2.1720

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 690/690 [==============================] - 1s 880us/step

# %%
# Calculate mean squared error
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# Mean Squared Error: 2.1471051891038067
# R-squared: 0.788724634416415

# %%
# Plot training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Next step is to try a more advanced net and possibly adjust activation functions

# %% [markdown]
# ## A more complex  net (2)

# %%
# Initialize model
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(64, kernel_initializer='normal', activation="relu", input_shape=(16,)),
    keras.layers.Dense(128, kernel_initializer='normal', activation="relu"),
    keras.layers.Dense(128, kernel_initializer='normal', activation="relu"),
    keras.layers.Dense(128, kernel_initializer='normal', activation="relu"),
    keras.layers.Dense(1, kernel_initializer='normal', activation="linear")
])

# Compile model
model.compile(optimizer="adam", loss="mean_absolute_error", metrics=["mean_absolute_error"])

# %%
# Train model
history = model.fit(X_train, y_train, epochs=100, batch_size=100, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 707/707 [==============================] - 5s 5ms/step - loss: 1.3004 - mean_absolute_error: 1.3004 - val_loss: 1.1798 - val_mean_absolute_error: 1.1798
# Epoch 2/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1479 - mean_absolute_error: 1.1479 - val_loss: 1.1357 - val_mean_absolute_error: 1.1357
# Epoch 3/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1395 - mean_absolute_error: 1.1395 - val_loss: 1.1717 - val_mean_absolute_error: 1.1717
# Epoch 4/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1391 - mean_absolute_error: 1.1391 - val_loss: 1.1645 - val_mean_absolute_error: 1.1645
# Epoch 5/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1380 - mean_absolute_error: 1.1380 - val_loss: 1.1325 - val_mean_absolute_error: 1.1325
# Epoch 6/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1366 - mean_absolute_error: 1.1366 - val_loss: 1.1543 - val_mean_absolute_error: 1.1543
# Epoch 7/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1307 - mean_absolute_error: 1.1307 - val_loss: 1.1982 - val_mean_absolute_error: 1.1982
# Epoch 8/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1346 - mean_absolute_error: 1.1346 - val_loss: 1.1329 - val_mean_absolute_error: 1.1329
# Epoch 9/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1340 - mean_absolute_error: 1.1340 - val_loss: 1.1287 - val_mean_absolute_error: 1.1287
# Epoch 10/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1285 - mean_absolute_error: 1.1285 - val_loss: 1.1289 - val_mean_absolute_error: 1.1289
# Epoch 11/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1313 - mean_absolute_error: 1.1313 - val_loss: 1.1515 - val_mean_absolute_error: 1.1515
# Epoch 12/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1277 - mean_absolute_error: 1.1277 - val_loss: 1.1347 - val_mean_absolute_error: 1.1347
# Epoch 13/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1287 - mean_absolute_error: 1.1287 - val_loss: 1.1367 - val_mean_absolute_error: 1.1367
# Epoch 14/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1285 - mean_absolute_error: 1.1285 - val_loss: 1.1438 - val_mean_absolute_error: 1.1438
# Epoch 15/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1281 - mean_absolute_error: 1.1281 - val_loss: 1.1456 - val_mean_absolute_error: 1.1456
# Epoch 16/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1268 - mean_absolute_error: 1.1268 - val_loss: 1.1685 - val_mean_absolute_error: 1.1685
# Epoch 17/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1268 - mean_absolute_error: 1.1268 - val_loss: 1.1346 - val_mean_absolute_error: 1.1346
# Epoch 18/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1263 - mean_absolute_error: 1.1263 - val_loss: 1.1287 - val_mean_absolute_error: 1.1287
# Epoch 19/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1249 - mean_absolute_error: 1.1249 - val_loss: 1.2071 - val_mean_absolute_error: 1.2071
# Epoch 20/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1260 - mean_absolute_error: 1.1260 - val_loss: 1.1585 - val_mean_absolute_error: 1.1585
# Epoch 21/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1269 - mean_absolute_error: 1.1269 - val_loss: 1.1312 - val_mean_absolute_error: 1.1312
# Epoch 22/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1248 - mean_absolute_error: 1.1248 - val_loss: 1.1294 - val_mean_absolute_error: 1.1294
# Epoch 23/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1246 - mean_absolute_error: 1.1246 - val_loss: 1.1386 - val_mean_absolute_error: 1.1386
# Epoch 24/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1237 - mean_absolute_error: 1.1237 - val_loss: 1.1401 - val_mean_absolute_error: 1.1401
# Epoch 25/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1263 - mean_absolute_error: 1.1263 - val_loss: 1.1247 - val_mean_absolute_error: 1.1247
# Epoch 26/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1234 - mean_absolute_error: 1.1234 - val_loss: 1.1279 - val_mean_absolute_error: 1.1279
# Epoch 27/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1240 - mean_absolute_error: 1.1240 - val_loss: 1.1331 - val_mean_absolute_error: 1.1331
# Epoch 28/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1248 - mean_absolute_error: 1.1248 - val_loss: 1.1391 - val_mean_absolute_error: 1.1391
# Epoch 29/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1245 - mean_absolute_error: 1.1245 - val_loss: 1.1281 - val_mean_absolute_error: 1.1281
# Epoch 30/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1229 - mean_absolute_error: 1.1229 - val_loss: 1.1269 - val_mean_absolute_error: 1.1269
# Epoch 31/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1233 - mean_absolute_error: 1.1233 - val_loss: 1.1338 - val_mean_absolute_error: 1.1338
# Epoch 32/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1231 - mean_absolute_error: 1.1231 - val_loss: 1.1245 - val_mean_absolute_error: 1.1245
# Epoch 33/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1220 - mean_absolute_error: 1.1220 - val_loss: 1.1447 - val_mean_absolute_error: 1.1447
# Epoch 34/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1238 - mean_absolute_error: 1.1238 - val_loss: 1.1248 - val_mean_absolute_error: 1.1248
# Epoch 35/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1225 - mean_absolute_error: 1.1225 - val_loss: 1.1485 - val_mean_absolute_error: 1.1485
# Epoch 36/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1222 - mean_absolute_error: 1.1222 - val_loss: 1.1287 - val_mean_absolute_error: 1.1287
# Epoch 37/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1207 - mean_absolute_error: 1.1207 - val_loss: 1.1278 - val_mean_absolute_error: 1.1278
# Epoch 38/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1200 - mean_absolute_error: 1.1200 - val_loss: 1.1333 - val_mean_absolute_error: 1.1333
# Epoch 39/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1215 - mean_absolute_error: 1.1215 - val_loss: 1.1260 - val_mean_absolute_error: 1.1260
# Epoch 40/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1209 - mean_absolute_error: 1.1209 - val_loss: 1.1269 - val_mean_absolute_error: 1.1269
# Epoch 41/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1198 - mean_absolute_error: 1.1198 - val_loss: 1.1281 - val_mean_absolute_error: 1.1281
# Epoch 42/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1244 - mean_absolute_error: 1.1244 - val_loss: 1.1309 - val_mean_absolute_error: 1.1309
# Epoch 43/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1209 - mean_absolute_error: 1.1209 - val_loss: 1.1320 - val_mean_absolute_error: 1.1320
# Epoch 44/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1198 - mean_absolute_error: 1.1198 - val_loss: 1.1285 - val_mean_absolute_error: 1.1285
# Epoch 45/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1221 - mean_absolute_error: 1.1221 - val_loss: 1.1242 - val_mean_absolute_error: 1.1242
# Epoch 46/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1194 - mean_absolute_error: 1.1194 - val_loss: 1.1278 - val_mean_absolute_error: 1.1278
# Epoch 47/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1225 - mean_absolute_error: 1.1225 - val_loss: 1.1224 - val_mean_absolute_error: 1.1224
# Epoch 48/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1182 - mean_absolute_error: 1.1182 - val_loss: 1.1253 - val_mean_absolute_error: 1.1253
# Epoch 49/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1187 - mean_absolute_error: 1.1187 - val_loss: 1.1357 - val_mean_absolute_error: 1.1357
# Epoch 50/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1180 - mean_absolute_error: 1.1180 - val_loss: 1.1248 - val_mean_absolute_error: 1.1248
# Epoch 51/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1192 - mean_absolute_error: 1.1192 - val_loss: 1.1247 - val_mean_absolute_error: 1.1247
# Epoch 52/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1205 - mean_absolute_error: 1.1205 - val_loss: 1.1294 - val_mean_absolute_error: 1.1294
# Epoch 53/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1174 - mean_absolute_error: 1.1174 - val_loss: 1.1270 - val_mean_absolute_error: 1.1270
# Epoch 54/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1193 - mean_absolute_error: 1.1193 - val_loss: 1.1494 - val_mean_absolute_error: 1.1494
# Epoch 55/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1181 - mean_absolute_error: 1.1181 - val_loss: 1.1421 - val_mean_absolute_error: 1.1421
# Epoch 56/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1179 - mean_absolute_error: 1.1179 - val_loss: 1.1362 - val_mean_absolute_error: 1.1362
# Epoch 57/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1167 - mean_absolute_error: 1.1167 - val_loss: 1.1258 - val_mean_absolute_error: 1.1258
# Epoch 58/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1171 - mean_absolute_error: 1.1171 - val_loss: 1.1231 - val_mean_absolute_error: 1.1231
# Epoch 59/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1177 - mean_absolute_error: 1.1177 - val_loss: 1.1434 - val_mean_absolute_error: 1.1434
# Epoch 60/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1174 - mean_absolute_error: 1.1174 - val_loss: 1.1347 - val_mean_absolute_error: 1.1347
# Epoch 61/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1178 - mean_absolute_error: 1.1178 - val_loss: 1.1246 - val_mean_absolute_error: 1.1246
# Epoch 62/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1171 - mean_absolute_error: 1.1171 - val_loss: 1.1328 - val_mean_absolute_error: 1.1328
# Epoch 63/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1162 - mean_absolute_error: 1.1162 - val_loss: 1.1249 - val_mean_absolute_error: 1.1249
# Epoch 64/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1158 - mean_absolute_error: 1.1158 - val_loss: 1.1250 - val_mean_absolute_error: 1.1250
# Epoch 65/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1163 - mean_absolute_error: 1.1163 - val_loss: 1.1325 - val_mean_absolute_error: 1.1325
# Epoch 66/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1169 - mean_absolute_error: 1.1169 - val_loss: 1.1256 - val_mean_absolute_error: 1.1256
# Epoch 67/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1157 - mean_absolute_error: 1.1157 - val_loss: 1.1254 - val_mean_absolute_error: 1.1254
# Epoch 68/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1164 - mean_absolute_error: 1.1164 - val_loss: 1.1346 - val_mean_absolute_error: 1.1346
# Epoch 69/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1155 - mean_absolute_error: 1.1155 - val_loss: 1.1334 - val_mean_absolute_error: 1.1334
# Epoch 70/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1172 - mean_absolute_error: 1.1172 - val_loss: 1.1345 - val_mean_absolute_error: 1.1345
# Epoch 71/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1146 - mean_absolute_error: 1.1146 - val_loss: 1.1238 - val_mean_absolute_error: 1.1238
# Epoch 72/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1152 - mean_absolute_error: 1.1152 - val_loss: 1.1220 - val_mean_absolute_error: 1.1220
# Epoch 73/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1161 - mean_absolute_error: 1.1161 - val_loss: 1.1264 - val_mean_absolute_error: 1.1264
# Epoch 74/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1154 - mean_absolute_error: 1.1154 - val_loss: 1.1309 - val_mean_absolute_error: 1.1309
# Epoch 75/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1157 - mean_absolute_error: 1.1157 - val_loss: 1.1243 - val_mean_absolute_error: 1.1243
# Epoch 76/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1143 - mean_absolute_error: 1.1143 - val_loss: 1.1392 - val_mean_absolute_error: 1.1392
# Epoch 77/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1154 - mean_absolute_error: 1.1154 - val_loss: 1.1239 - val_mean_absolute_error: 1.1239
# Epoch 78/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1136 - mean_absolute_error: 1.1136 - val_loss: 1.1258 - val_mean_absolute_error: 1.1258
# Epoch 79/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1154 - mean_absolute_error: 1.1154 - val_loss: 1.1311 - val_mean_absolute_error: 1.1311
# Epoch 80/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1147 - mean_absolute_error: 1.1147 - val_loss: 1.1275 - val_mean_absolute_error: 1.1275
# Epoch 81/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1141 - mean_absolute_error: 1.1141 - val_loss: 1.1305 - val_mean_absolute_error: 1.1305
# Epoch 82/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1144 - mean_absolute_error: 1.1144 - val_loss: 1.1310 - val_mean_absolute_error: 1.1310
# Epoch 83/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1144 - mean_absolute_error: 1.1144 - val_loss: 1.1265 - val_mean_absolute_error: 1.1265
# Epoch 84/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1132 - mean_absolute_error: 1.1132 - val_loss: 1.1307 - val_mean_absolute_error: 1.1307
# Epoch 85/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1156 - mean_absolute_error: 1.1156 - val_loss: 1.1264 - val_mean_absolute_error: 1.1264
# Epoch 86/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1144 - mean_absolute_error: 1.1144 - val_loss: 1.1233 - val_mean_absolute_error: 1.1233
# Epoch 87/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1131 - mean_absolute_error: 1.1131 - val_loss: 1.1240 - val_mean_absolute_error: 1.1240
# Epoch 88/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1157 - mean_absolute_error: 1.1157 - val_loss: 1.1291 - val_mean_absolute_error: 1.1291
# Epoch 89/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1142 - mean_absolute_error: 1.1142 - val_loss: 1.1224 - val_mean_absolute_error: 1.1224
# Epoch 90/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1118 - mean_absolute_error: 1.1118 - val_loss: 1.1243 - val_mean_absolute_error: 1.1243
# Epoch 91/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1140 - mean_absolute_error: 1.1140 - val_loss: 1.1278 - val_mean_absolute_error: 1.1278
# Epoch 92/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1127 - mean_absolute_error: 1.1127 - val_loss: 1.1284 - val_mean_absolute_error: 1.1284
# Epoch 93/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1133 - mean_absolute_error: 1.1133 - val_loss: 1.1214 - val_mean_absolute_error: 1.1214
# Epoch 94/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1116 - mean_absolute_error: 1.1116 - val_loss: 1.1258 - val_mean_absolute_error: 1.1258
# Epoch 95/100
# 707/707 [==============================] - 4s 5ms/step - loss: 1.1128 - mean_absolute_error: 1.1128 - val_loss: 1.1261 - val_mean_absolute_error: 1.1261
# Epoch 96/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1137 - mean_absolute_error: 1.1137 - val_loss: 1.1358 - val_mean_absolute_error: 1.1358
# Epoch 97/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1142 - mean_absolute_error: 1.1142 - val_loss: 1.1250 - val_mean_absolute_error: 1.1250
# Epoch 98/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1136 - mean_absolute_error: 1.1136 - val_loss: 1.1503 - val_mean_absolute_error: 1.1503
# Epoch 99/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1118 - mean_absolute_error: 1.1118 - val_loss: 1.1370 - val_mean_absolute_error: 1.1370
# Epoch 100/100
# 707/707 [==============================] - 3s 5ms/step - loss: 1.1134 - mean_absolute_error: 1.1134 - val_loss: 1.1240 - val_mean_absolute_error: 1.1240

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 690/690 [==============================] - 2s 2ms/step

# %%
# Calculate mean squared error
from sklearn.metrics import mean_absolute_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# Mean Absolute Error: 1.116717130609454
# R-squared: 0.785647837503616

# %%
# Plot training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
